# %%
# p = -2 alpha = 1.0 beta = 0.1
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2022
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    # MF can be implemented by setting the number of layers of LightGCN to 0.
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 27879, 'n_items': 10429}
# loading over ...
# start training ...
# +-------+-------------------+-------------------+------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |       Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   0   | 3.830340623855591 | 5.911604642868042 | 52.0518913269043 | [0.00838672 0.01435437] | [0.00454229 0.00593995] | [0.00077276 0.00055409] | [0.01483325 0.0264606 ] |
# +-------+-------------------+-------------------+------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.8070s, training loss at epoch 1: 51.9781
# using time 3.7990s, training loss at epoch 2: 51.8086
# using time 3.7957s, training loss at epoch 3: 51.2894
# using time 3.9009s, training loss at epoch 4: 50.3166
# +-------+------------------+-------------------+------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch | training time(s) |   tesing time(s)  |       Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+------------------+-------------------+------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   5   | 3.79103422164917 | 5.894155502319336 | 48.9737434387207 | [0.09686116 0.14917767] | [0.05350453 0.06564003] | [0.00908656 0.00561845] | [0.15483994 0.2303938 ] |
# +-------+------------------+-------------------+------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7992s, training loss at epoch 6: 47.3982
# using time 3.8640s, training loss at epoch 7: 45.6663
# using time 3.7774s, training loss at epoch 8: 43.8128
# using time 3.7811s, training loss at epoch 9: 41.8423
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   10  | 3.770087480545044 | 5.687122106552124 | 39.747535705566406 | [0.11233126 0.17218984] | [0.06135838 0.0753539 ] | [0.0104383  0.00648165] | [0.17823819 0.26321834] |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7707s, training loss at epoch 11: 37.5290
# using time 3.7797s, training loss at epoch 12: 35.2313
# using time 3.7475s, training loss at epoch 13: 32.8825
# using time 3.7853s, training loss at epoch 14: 30.5406
# +-------+-------------------+--------------------+--------------------+-------------------------+-----------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |          recall         |          ndcg         |        precision        |        hit_ratio        |
# +-------+-------------------+--------------------+--------------------+-------------------------+-----------------------+-------------------------+-------------------------+
# |   15  | 3.687859058380127 | 5.7271528244018555 | 28.251691818237305 | [0.12227012 0.18848323] | [0.0669444 0.0823586] | [0.01130198 0.00704531] | [0.19335853 0.28527681] |
# +-------+-------------------+--------------------+--------------------+-------------------------+-----------------------+-------------------------+-------------------------+
# using time 3.7393s, training loss at epoch 16: 26.0202
# using time 3.7250s, training loss at epoch 17: 23.8942
# using time 3.7901s, training loss at epoch 18: 21.8607
# using time 3.7026s, training loss at epoch 19: 19.9632
# +-------+-------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   20  | 3.694669008255005 | 5.887078523635864 | 18.18570327758789 | [0.12748528 0.19660866] | [0.06992805 0.08597931] | [0.01179243 0.00732858] | [0.2013015  0.29604287] |
# +-------+-------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7236s, training loss at epoch 21: 16.5455
# using time 3.7171s, training loss at epoch 22: 15.0240
# using time 3.7885s, training loss at epoch 23: 13.6337
# using time 3.6952s, training loss at epoch 24: 12.3658
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   25  | 3.699289560317993 | 5.876031875610352 | 11.209307670593262 | [0.12909496 0.19958076] | [0.07090814 0.08727516] | [0.01196469 0.00743768] | [0.20407675 0.30092349] |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7513s, training loss at epoch 26: 10.1638
# using time 3.7236s, training loss at epoch 27: 9.2125
# using time 3.7941s, training loss at epoch 28: 8.3532
# using time 3.7090s, training loss at epoch 29: 7.5818
# +-------+--------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   30  | 3.7173733711242676 | 5.932702541351318 | 6.8809709548950195 | [0.12963517 0.20030125] | [0.07131766 0.0876868 ] | [0.01201254 0.00746064] | [0.20484234 0.30159338] |
# +-------+--------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7265s, training loss at epoch 31: 6.2535
# using time 3.7237s, training loss at epoch 32: 5.6876
# using time 3.7242s, training loss at epoch 33: 5.1835
# using time 3.7213s, training loss at epoch 34: 4.7254
# +-------+-------------------+--------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+--------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   35  | 3.806305170059204 | 5.8540730476379395 | 4.314402103424072 | [0.12969158 0.19935263] | [0.07123873 0.08738691] | [0.01200536 0.00742524] | [0.20484234 0.29996651] |
# +-------+-------------------+--------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7210s, training loss at epoch 36: 3.9445
# using time 3.7222s, training loss at epoch 37: 3.6145
# using time 3.7222s, training loss at epoch 38: 3.3156
# using time 3.7849s, training loss at epoch 39: 3.0468
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   40  | 3.6938774585723877 | 5.875439405441284 | 2.801395893096924 | [0.1303632  0.19880938] | [0.07105648 0.08690256] | [0.01204842 0.00740131] | [0.20522513 0.29929662] |
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.6961s, training loss at epoch 41: 2.5822
# using time 3.6870s, training loss at epoch 42: 2.3831
# using time 3.7033s, training loss at epoch 43: 2.2040
# using time 3.7113s, training loss at epoch 44: 2.0419
# +-------+--------------------+-----------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |  tesing time(s) |        Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-----------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   45  | 3.7852373123168945 | 5.9727942943573 | 1.8943893909454346 | [0.12926103 0.19788132] | [0.07048853 0.08640886] | [0.01195751 0.00737547] | [0.20355041 0.29819609] |
# +-------+--------------------+-----------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7196s, training loss at epoch 46: 1.7598
# using time 3.7108s, training loss at epoch 47: 1.6381
# using time 3.7170s, training loss at epoch 48: 1.5274
# using time 3.7130s, training loss at epoch 49: 1.4256
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   50  | 3.7087254524230957 | 5.903318166732788 | 1.334643006324768 | [0.12846071 0.19723703] | [0.07001972 0.08598427] | [0.01189052 0.00735633] | [0.20268912 0.29680846] |
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7296s, training loss at epoch 51: 1.2512
# using time 3.8078s, training loss at epoch 52: 1.1739
# using time 3.7160s, training loss at epoch 53: 1.1025
# using time 3.7116s, training loss at epoch 54: 1.0377
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   55  | 3.709001064300537 | 5.900284290313721 | 0.9785150289535522 | [0.12784594 0.19667101] | [0.06951395 0.08547426] | [0.01184746 0.00734294] | [0.20168429 0.29585148] |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7288s, training loss at epoch 56: 0.9236
# using time 3.7918s, training loss at epoch 57: 0.8732
# using time 3.7043s, training loss at epoch 58: 0.8267
# using time 3.7047s, training loss at epoch 59: 0.7840
# +-------+--------------------+-------------------+--------------------+-------------------------+-------------------------+-----------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |          recall         |           ndcg          |       precision       |        hit_ratio        |
# +-------+--------------------+-------------------+--------------------+-------------------------+-------------------------+-----------------------+-------------------------+
# |   60  | 3.7814431190490723 | 5.844568490982056 | 0.7442948222160339 | [0.12699361 0.19540838] | [0.06907132 0.08495234] | [0.0117709 0.007297 ] | [0.20015312 0.29417675] |
# +-------+--------------------+-------------------+--------------------+-------------------------+-------------------------+-----------------------+-------------------------+
# using time 3.6964s, training loss at epoch 61: 0.7079
# using time 3.7032s, training loss at epoch 62: 0.6737
# using time 3.7022s, training loss at epoch 63: 0.6422
# using time 3.7004s, training loss at epoch 64: 0.6135
# +-------+-------------------+------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |  tesing time(s)  |        Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   65  | 3.701781988143921 | 5.98241925239563 | 0.586220920085907 | [0.12692704 0.19444633] | [0.06868033 0.08435139] | [0.01172544 0.00726255] | [0.19972247 0.29317192] |
# +-------+-------------------+------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7157s, training loss at epoch 66: 0.5610
# using time 3.7880s, training loss at epoch 67: 0.5378
# using time 3.7095s, training loss at epoch 68: 0.5160
# using time 3.7048s, training loss at epoch 69: 0.4958
# +-------+--------------------+-------------------+--------------------+-----------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |         recall        |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-------------------+--------------------+-----------------------+-------------------------+-------------------------+-------------------------+
# |   70  | 3.7157835960388184 | 5.852855682373047 | 0.4768138527870178 | [0.1268273 0.1928786] | [0.06827432 0.08361763] | [0.01170869 0.00720609] | [0.19967463 0.29101871] |
# +-------+--------------------+-------------------+--------------------+-----------------------+-------------------------+-------------------------+-------------------------+
# using time 3.8199s, training loss at epoch 71: 0.4589
# using time 3.7206s, training loss at epoch 72: 0.4424
# using time 3.7207s, training loss at epoch 73: 0.4272
# using time 3.7210s, training loss at epoch 74: 0.4129
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   75  | 3.721926689147949 | 5.844671964645386 | 0.3994053602218628 | [0.12590258 0.19136357] | [0.06736618 0.08259198] | [0.01163453 0.00716207] | [0.1981913  0.28929614] |
# +-------+-------------------+-------------------+--------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7143s, training loss at epoch 76: 0.3869
# using time 3.8059s, training loss at epoch 77: 0.3750
# using time 3.7288s, training loss at epoch 78: 0.3638
# using time 3.7301s, training loss at epoch 79: 0.3534
# +-------+--------------------+-------------------+---------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |         Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-------------------+---------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   80  | 3.7215330600738525 | 5.807052135467529 | 0.34369853138923645 | [0.12461338 0.19029773] | [0.06627484 0.08154178] | [0.01153883 0.00712091] | [0.19651658 0.28757357] |
# +-------+--------------------+-------------------+---------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7168s, training loss at epoch 81: 0.3345
# using time 3.7040s, training loss at epoch 82: 0.3259
# using time 3.6998s, training loss at epoch 83: 0.3176
# using time 3.8067s, training loss at epoch 84: 0.3102
# +-------+-------------------+-------------------+---------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s) |   tesing time(s)  |         Loss        |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+-------------------+-------------------+---------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   85  | 3.751290798187256 | 6.020021438598633 | 0.30309680104255676 | [0.12349384 0.18887851] | [0.06519358 0.08039309] | [0.01142638 0.0070635 ] | [0.19460261 0.28551605] |
# +-------+-------------------+-------------------+---------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# using time 3.7408s, training loss at epoch 86: 0.2962
# using time 3.7250s, training loss at epoch 87: 0.2898
# using time 3.7370s, training loss at epoch 88: 0.2840
# using time 3.8011s, training loss at epoch 89: 0.2783
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |          recall         |           ndcg          |        precision        |        hit_ratio        |
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   90  | 3.7197446823120117 | 5.841760158538818 | 0.273118257522583 | [0.12247741 0.18708843] | [0.06410635 0.07912865] | [0.01133308 0.00699746] | [0.19316714 0.28278865] |
# +-------+--------------------+-------------------+-------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# Early stopping is trigger at step: 10 log:0.1224774112650048
# early stopping at 90, recall@20:0.1304
